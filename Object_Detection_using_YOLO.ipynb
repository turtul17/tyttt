# %% [markdown]
# <a href="https://colab.research.google.com/github/turtul17/tyttt/blob/main/Object_Detection_using_YOLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# EXPERIMENT NO:- 04
# TUSHAR BORUDE
# FCC03

# %%
# !pip install ultralytics

from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
from google.colab import files

print("Upload an image")
uploaded = files.upload()
image_path = list(uploaded.keys())[0]

model = YOLO('yolov8n.pt')

print("\nOutput 1: Running Object Detection")
results = model(image_path)

img = cv2.imread(image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

annotated = results[0].plot()

plt.imshow(annotated)
plt.title("Detected Objects (YOLO)")
plt.axis('off')
plt.show()

print("\nOutput 2: Detected Objects Details")
for box in results[0].boxes:
    cls = int(box.cls[0])
    conf = float(box.conf[0])
    print("Object:", model.names[cls], "| Confidence:", round(conf, 2))
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 19.4 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Upload an image
#      <input type="file" id="files-ae6db249-e47c-4c63-871e-ed665cca5e02" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ae6db249-e47c-4c63-871e-ed665cca5e02">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# ...
